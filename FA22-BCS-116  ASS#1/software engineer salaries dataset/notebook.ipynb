# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Path = 'drive/My Drive/DATASETS'

# %%
import pandas as pd
df = pd.read_csv (Path+'/Software Engineer Salaries.csv')
df.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary
# 0   $68K - $94K (Glassdoor est.)
# 1   $61K - $104K (Employer est.)
# 2  $95K - $118K (Glassdoor est.)
# 3   $97K - $145K (Employer est.)
# 4  $85K - $108K (Glassdoor est.)

# %%
# @title Company Score

from matplotlib import pyplot as plt
df['Company Score'].plot(kind='hist', bins=20, title='Company Score')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
print("First 5 rows of the dataset:")
print (df.head())
# Out:
# First 5 rows of the dataset:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary
# 0   $68K - $94K (Glassdoor est.)
# 1   $61K - $104K (Employer est.)
# 2  $95K - $118K (Glassdoor est.)
# 3   $97K - $145K (Employer est.)
# ...

# %%
print("/nBasic information about the dataset:")
print(df.info())
# Out:
# /nBasic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        868 non-null    object
#  1   Company Score  789 non-null    float64
#  2   Job Title      870 non-null    object
#  3   Location       857 non-null    object
#  4   Date           870 non-null    object
#  5   Salary         764 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 40.9+ KB
# None

# %%
print("/nSummary statistics for numerical columns:")
print(df.describe())
# Out:
# /nSummary statistics for numerical columns:
#        Company Score
# count     789.000000
# mean        3.895311
# std         0.524952
# min         1.000000
# 25%         3.600000
# 50%         3.900000
# 75%         4.200000
# max         5.000000

# %%
print("/nMissing values in the dataset:")
print(df.isnull())
# Out:
# /nMissing values in the dataset:
#      Company  Company Score  Job Title  Location   Date  Salary
# 0      False          False      False     False  False   False
# 1      False          False      False     False  False   False
# 2      False          False      False     False  False   False
# 3      False          False      False     False  False   False
# 4      False          False      False     False  False   False
# ..       ...            ...        ...       ...    ...     ...
# 865    False           True      False     False  False    True
# 866    False           True      False     False  False    True
# 867    False           True      False     False  False    True
# 868     True           True      False     False  False    True
# 869     True           True      False     False  False    True
#
# [870 rows x 6 columns]
