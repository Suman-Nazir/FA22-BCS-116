# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Path = 'drive/My Drive/DATASETS'

# %%
import pandas as pd
df = pd.read_csv (Path+'/description.csv')
df.head()
# Out:
#    Unnamed: 0 Column Names         Explanation
# 0           0        State               State
# 1           1         Year                Year
# 2           2         Rape   No. of Rape cases
# 3           3          K&A  Kidnap And Assault
# 4           4           DD        Dowry Deaths

# %%
print("First 5 rows of the dataset:")
print (df.head())
# Out:
# First 5 rows of the dataset:
#    Unnamed: 0 Column Names         Explanation
# 0           0        State               State
# 1           1         Year                Year
# 2           2         Rape   No. of Rape cases
# 3           3          K&A  Kidnap And Assault
# 4           4           DD        Dowry Deaths

# %%
print("/nBasic information about the dataset:")
print(df.info())
# Out:
# /nBasic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9 non-null      int64
#  1   Column Names  9 non-null      object
#  2   Explanation   9 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 344.0+ bytes
# None

# %%
print("/nSummary statistics for numerical columns:")
print(df.describe())
# Out:
# /nSummary statistics for numerical columns:
#        Unnamed: 0
# count    9.000000
# mean     4.000000
# std      2.738613
# min      0.000000
# 25%      2.000000
# 50%      4.000000
# 75%      6.000000
# max      8.000000

# %%
print("/nMissing values in the dataset:")
print(df.isnull())
# Out:
# /nMissing values in the dataset:
#    Unnamed: 0  Column Names  Explanation
# 0       False         False        False
# 1       False         False        False
# 2       False         False        False
# 3       False         False        False
# 4       False         False        False
# 5       False         False        False
# 6       False         False        False
# 7       False         False        False
# 8       False         False        False
